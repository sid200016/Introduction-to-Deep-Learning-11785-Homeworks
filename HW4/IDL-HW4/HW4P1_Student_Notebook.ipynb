# %% [markdown]
# # Setup
# -  Follow the setup instructions based on your preferred environment!

# %% [markdown]
# ## Local

# %% [markdown]
# One of our key goals in designing this assignment is to allow you to complete most of the preliminary implementation work locally.
# We highly recommend that you **pass all tests locally** using the provided `hw4_data_subset` before moving to a GPU runtime.
# To do this, simply:
#
# ### Create a new conda environment
# ```bash
# # Be sure to deactivate any active environments first
# conda create -n hw4 python=3.12.4
# ```
#
# ### Activate the conda environment
# ```bash
# conda activate hw4
# ```
#
# ### Install the dependencies using the provided `requirements.txt`
# ```bash
# pip install --no-cache-dir --ignore-installed -r requirements.txt
# ```
#
# ### Ensure that your notebook is in the same working directory as the `Handout`
# This can be achieved by:
# 1. Physically moving the notebook into the handout directory.
# 2. Changing the notebook’s current working directory to the handout directory using the os.chdir() function.
#
# ### Open the notebook and select the newly created environment from the kernel selector.
#
# If everything was done correctly, You should see atleast the following files in your current working directory after running `!ls`:
# ```
# .
# ├── README.md
# ├── requirements.txt
# ├── hw4lib/
# ├── mytorch/
# ├── tests/
# └── hw4_data_subset/
# ```

# %% [markdown]
# ## Colab

# %% [markdown]
# ### Step 1: Get your handout
# - See writeup for recommended approaches.

# %%
# Example: My preferred approach
import os
# Settings -> Developer Settings -> Personal Access Tokens -> Token (classic)
os.environ['GITHUB_TOKEN'] = "your_token_here"

GITHUB_USERNAME = "your_username_here"
REPO_NAME       = "your_repo_name_here"
TOKEN = os.environ.get("GITHUB_TOKEN")
repo_url        = f"https://{TOKEN}@github.com/{GITHUB_USERNAME}/{REPO_NAME}.git"
# !git clone {repo_url}

# %%
# To pull latest changes (Must be in the repo dir, use pwd/ls to verify)
# !cd {REPO_NAME} && git pull

# %% [markdown]
# ### Step 2: Install Dependencies
# - `NOTE`: Your runtime will be restarted to ensure all dependencies are updated.
# - `NOTE`: You will see a runtime crashed message, this was intentionally done. Simply move on to the next cell.

# %%
# %pip install --no-deps -r IDL-HW4/requirements.txt
import os
os.kill(os.getpid(), 9) # NOTE: This will restart the your colab Python runtime (required)!

# %% [markdown]
# ### Step 3: Obtain Data
#
# - `NOTE`: This process will automatically download and unzip data for both `HW4P1` and `HW4P2`.

# %%
# !curl -L -o /content/f25-hw4-data.zip https://www.kaggle.com/datasets/cmu11785/f25-11785-hw4-data
# !unzip -q -o /content/f25-hw4-data.zip -d /content/hw4_data
# !rm -rf /content/f25-hw4-data.zip
# !du -h --max-depth=2 /content/hw4_data

# %% [markdown]
# ### Step 4: Move to Handout Directory
# You must be within the handout directory for the library imports to work!
#
# - `NOTE`: You may have to repeat running this command anytime you restart your runtime.
# - `NOTE`: You can do a `pwd` to check if you are in the right directory.
# - `NOTE`: The way it is setup currently, Your data directory should be one level up from your project directory. Keep this in mind when you are setting your `root` in the config file.
#
# If everything was done correctly, You should see atleast the following files in your current working directory after running `!ls`:
# ```
# .
# ├── README.md
# ├── requirements.txt
# ├── hw4lib/
# ├── mytorch/
# ├── tests/
# └── hw4_data_subset/
#
# ```

# %%
import os
os.chdir('IDL-HW4')
# !ls

# %% [markdown]
# ## Kaggle

# %% [markdown]
# While it is possible to run the notebook on Kaggle, we would recommend against it. This assignment is more resource intensive and may run slower on Kaggle.

# %% [markdown]
# ### Step 1: Get your handout
# - See writeup for recommended approaches.

# %%
# Example: My preferred approach
import os
# Settings -> Developer Settings -> Personal Access Tokens -> Token (classic)
os.environ['GITHUB_TOKEN'] = "your_token_here"

GITHUB_USERNAME = "your_username_here"
REPO_NAME       = "your_repo_name_here"
TOKEN = os.environ.get("GITHUB_TOKEN")
repo_url        = f"https://{TOKEN}@github.com/{GITHUB_USERNAME}/{REPO_NAME}.git"
# !git clone {repo_url}

# %%
# To pull latest changes (Must be in the repo dir, use pwd/ls to verify)
# !cd {REPO_NAME} && git pull

# %% [markdown]
# ### Step 2: Install Dependencies
# - Simply set the `Environment` setting in the notebook to `Always use latest environment`. No need to install anything.

# %% [markdown]
# ### Step 3: Obtain Data
#
# #### ⚠️ Important: Kaggle Users
# If you are using Kaggle, **do not manually download the data!** The dataset is large and may exceed your available disk space. Instead, follow these steps to add the dataset directly to your notebook:
#
# 1. Open your **Kaggle Notebook**.
# 2. Navigate to **Notebook → Input**.
# 3. Click **Add Input**.
# 4. In the search bar, paste the following URL:
#    👉 [https://www.kaggle.com/datasets/cmu11785/f25-11785-hw4-data](https://www.kaggle.com/datasets/cmu11785/f25-11785-hw4-data)
# 5. Click the **➕ (plus sign)** to add the dataset to your notebook.
#
# #### 📌 Note:
# This process will automatically download and unzip data for both `HW4P1` and `HW4P2`.

# %% [markdown]
# ### Step 4: Move to Handout Directory
# You must be within the handout directory for the library imports to work!
#
# - `NOTE`: You may have to repeat running this command anytime you restart your runtime.
# - `NOTE`: You can do a `pwd` to check if you are in the right directory.
# - `NOTE`: The way it is setup currently, Your data directory should be one level up from your project directory. Keep this in mind when you are setting your `root` in the config file.
#
# If everything was done correctly, You should see atleast the following files in your current working directory after running `!ls`:
# ```
# .
# ├── README.md
# ├── requirements.txt
# ├── hw4lib/
# ├── mytorch/
# ├── tests/
# └── hw4_data_subset/
#
# ```

# %%
import os
os.chdir('IDL-HW4')
# !ls

# %% [markdown]
# ## PSC

# %% [markdown]
# ### 1️⃣ **Step 1 Setting Up Your Environment on Bridges2**
#
# ❗️⚠️ For this homework, we are **providing shared Datasets and a shared Conda environment** for the entire class.
#
# ❗️⚠️ So for PSC users, **do not download the data yourself** and **do not need to manually install the packages**!

# %% [markdown]
# Follow these steps to set up the environment and start a Jupyter notebook on Bridges2:
#
# To run your notebook more efficiently on PSC, we need to use a **Jupyter Server** hosted on a compute node.
#
# You can use your prefered way of connecting to the Jupyter Server. Your options should be covered in the docs linked in post 558 @ piazza.

# %% [markdown]
# **The recommended way of connecting is:**
#
# #### **Connect in VSCode**
# SSH into Bridges2 and navigate to your **Jet directory** (`Jet/home/<your_psc_username>`). Upload your notebook there, and then connect to the Jupyter Server from that directory.

# %% [markdown]
# #### **1. SSH into Bridges2**
# 1）Open VS Code and click on the `Extensions` icon in the left sidebar. Make sure the "**Remote - SSH**" extension is installed.
#
# 2）Open the command palette (**Shift+Command+P** on Mac, **Ctrl+Shift+P** on Windows). A search box will appear at the top center. Choose `"Remote-SSH: Add New SSH Host"`, then enter:
#
# ```bash
# ssh <your_username>@bridges2.psc.edu #change <your_username> to your username
# ```
#
# Next, choose `"/Users/<your_username>/.ssh/config"` as the config file. A dialog will appear in the bottom right saying "Host Added". Click `"Connect"`, and then enter your password.
#
# (Note: After adding the host once, you can later use `"Remote-SSH: Connect to Host"` and select "bridges2.psc.edu" from the list.)
#
# 3）Once connected, click `"Explorer"` in the left sidebar > "Open Folder", and navigate to your home directory under the project grant:
# ```bash
# /jet/home/<your_username>  #change <your_username> to your username
# ```
#
# 4）You can now drag your notebook files directly into the right-hand pane (your remote home directory), or upload them using `scp` into your folder.

# %% [markdown]
# > ❗️⚠️ The following steps should be executed in the **VSCode integrated terminal**.

# %% [markdown]
# #### **2. Navigate to Your Directory**
# Make sure to use this `/jet/home/<your_username>` as your working directory, since all subsequent operations (up to submission) are based on this path.
# ```bash
# cd /jet/home/<your_username>  #change <your_username> to your username
# ```

# %% [markdown]
# #### **3. Request a Compute Node**
# ```bash
# interact -p GPU-shared --gres=gpu:v100-32:1 -t 8:00:00 -A cis250019p
# ```

# %% [markdown]
# #### **4. Load the Anaconda Module**
# ```bash
# module load anaconda3
# ```

# %% [markdown]
# #### **5. Activate the provided HW4 Environment**
# ```bash
# conda deactivate # First, deactivate any existing Conda environment
# conda activate /ocean/projects/cis250019p/mzhang23/TA/HW4/envs/hw4_env && export PYTHONNOUSERSITE=1
# ```

# %% [markdown]
# #### **6. Start Jupyter Notebook**
# Launch Jupyter Notebook:
# ```bash
# jupyter notebook --no-browser --ip=0.0.0.0
# ```
#
# Go to **Kernel** → **Select Another Kernel** → **Existing Jupyter Server**
#    Enter the URL of the Jupyter Server:```http://{hostname}:{port}/tree?token={token}```
#
#    *(Usually, this URL appears in the terminal output after you run `jupyter notebook --no-browser --ip=0.0.0.0`, in a line like:  “Jupyter Server is running at: http://...”)*
#
#    - eg: `http://v011.ib.bridges2.psc.edu:8888/tree?token=e4b302434e68990f28bc2b4ae8d216eb87eecb7090526249`
#
# > **Note**: Replace `{hostname}`, `{port}` and `{token}` with your actual values from the Jupyter output.

# %% [markdown]
# After launching the Jupyter notebook, you can run the cells directly inside the notebook — no need to use the terminal for the remaining steps.

# %% [markdown]
# ### 2️⃣ Step 2: Get Repo

# %%
#Make sure you are in your directory
# !pwd #should be /jet/home/<your_username>, if not, uncomment the following line and replace with your actual username:
# %cd /jet/home/<your_username>
#TODO: replace the "<your_username>" to yours

# %%
# Example: My preferred approach
import os
# Settings -> Developer Settings -> Personal Access Tokens -> Token (classic)
os.environ['GITHUB_TOKEN'] = "your_github_token_here"

GITHUB_USERNAME = "your_github_username_here"
REPO_NAME       = "your_github_repo_name_here"
TOKEN = os.environ.get("GITHUB_TOKEN")
repo_url        = f"https://{TOKEN}@github.com/{GITHUB_USERNAME}/{REPO_NAME}.git"
# !git clone {repo_url}

# %%
# To pull latest changes (Must be in the repo dir, use pwd/ls to verify)
# !cd {REPO_NAME} && git pull

# %% [markdown]
# #### **Move to Project Directory**
# - `NOTE`: You may have to repeat this on anytime you restart your runtime. You can do a `pwd` or `ls` to check if you are in the right directory.

# %%
import os
os.chdir('IDL-HW4')
# !ls

# %% [markdown]
# ### 3️⃣ **Step 3: Set up Kaggle API Authentication**

# %%
# TODO: Use the same Kaggle code from HW3P2
# !mkdir /jet/home/<your_username>/.kaggle #TODO: replace the "<your_username>" to yours

with open("/jet/home/<your_username>/.kaggle/kaggle.json", "w+") as f: #TODO: replace the "<your_username>" to yours
    f.write('{"username":"<your_username>","key":"<your_key>"}')
    # TODO: Put your kaggle username & key here

# !chmod 600 /jet/home/<your_username>/.kaggle/kaggle.json #TODO: replace the "<your_username>" to yours

# %% [markdown]
# ### 4️⃣ **Step 4: Get Data**
#
# ❗️⚠️ The data used in this assignment is **already stored in a shared, read-only folder, so you do not need to manually download anything**.
#
# Instead, just make sure to replace the dataset path in your notebook code with the correct path from the shared directory.
#
# You can run the following block to explore the shared directory structure:

# %%
import os
data_path = "/ocean/projects/cis250019p/mzhang23/TA/HW4/hw4p1_data" #Shared data path, do not need to change the username to yours
print("Files in shared hw4p2 dataset:", os.listdir(data_path))

# %%
# !apt-get install tree
# !tree -L 2 /ocean/projects/cis250019p/mzhang23/TA/HW4/hw4p1_data

# %% [markdown]
# # Imports
#
# - If your setup was done correctly, you should be able to run the following cell without any issues.

# %%
from hw4lib.data import (
    H4Tokenizer,
    LMDataset,
    verify_dataloader
)
from hw4lib.model import (
    CausalMask,
    PadMask,
    PositionalEncoding,
    DecoderOnlyTransformer
)
from hw4lib.utils import (
    create_optimizer,
    create_scheduler,
    plot_lr_schedule
)
from hw4lib.trainers import (
    LMTrainer,
)
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import yaml
import gc
import torch
from torchinfo import summary
import os
import json
import tarfile
import shutil
import wandb
import yaml
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %% [markdown]
# # Implementations
#
# - `NOTE`: All of these implementations have detailed specification, implementation details, and hints in their respective source files. Make sure to read all of them in their entirety to understand the implementation details!

# %% [markdown]
# ## MyTorch Implementations
# - Modify your `Linear` implementation from HW1P1 to support arbitrary number of dimensions in `mytorch/nn/linear.py`.
# - Modify your `Softmax` implementation from HW1P1 to support arbitrary number of dimensions in `mytorch/nn/activation.py`.
# - Implement the `ScaledDotProductAttention` class in `mytorch/nn/scaled_dot_product_attention.py`.
# - Implement the `MultiHeadAttention` class in `mytorch/nn/multi_head_attention.py`.
# - Run the cell below to check your implementations.

# %%
# !python -m tests.test_mytorch

# %% [markdown]
# ## Dataset Implementation
# - Familiarize yourself with the `tokenize`, `encode`, and `decode` methods of the `H4Tokenizer` class in `hw4lib/data/tokenizer.py`. You will need to make use of these methods in both `HW4P1` and `HW4P2` both in the dataset implementations and during decoding.
# - Implement the `LMDataset` class in `hw4lib/data/lm_dataset.py`.
#     - You will have to implement parts of `__init__` and completely implement the `__len__`, `__getitem__` and `collate_fn` methods.
# - Run the cell below to check your implementation.

# %%
# !python -m tests.test_dataset_lm

# %% [markdown]
# ## Model Implementations
# #### Overview:
# - Implement the `CausalMask` and `PadMask` functions in `hw4lib/modules/masks.py` to handle masking.
# - Implement the `PositionalEncoding` class in `hw4lib/model/positional_encoding.py` to handle positional encoding.
# - Implement the Transformer Sublayers: `SelfAttentionLayer` and `FeedForwardLayer` classes in `hw4lib/model/sublayers.py`.
# - Implement the Transformer Layer: `SelfAttentionDecoderLayer` class in `hw4lib/model/decoder_layers.py`.
# - Implement the `DecoderOnlyTransformer` class in `hw4lib/model/transformers.py`.
# - Run the cells below to check your implementation.
# - `NOTE`: Besides the `DecoderOnlyTransformer` (P1 mandatory, P2 optional), you will use all of the above implementations in both `HW4P1` and `HW4P2`!

# %% [markdown]
# ### Masks
# - Implement the `PadMask` and `CausalMask` functions in `hw4lib/modules/masks.py`.
# - Run the cell below to check your implementation.
# - You will need to make use of these masks in both `HW4P1` and `HW4P2`.

# %% [markdown]
# #### Causal Mask

# %%
# !python -m tests.test_mask_causal

# %% [markdown]
# #### Padding Mask

# %%
# !python -m tests.test_mask_padding

# %% [markdown]
# #### Optional: Visualize your Masks

# %%
# Dummy data

_d_model   = 64
_x         = torch.zeros(4, 20, _d_model)
_x_len     = torch.tensor([5, 15, 10, 20])
_x_causal  = CausalMask(_x)
_x_padding = PadMask(_x, _x_len)

# Create figure with two subplots side by side
fig, mask_axs = plt.subplots(1, 2, figsize=(12, 4))

# Plot masks
masks_and_titles = [
    (_x_padding, "Padding Mask"),
    (_x_causal, "Causal Mask")
]

# Plot each mask
images = []
for i, (mask, title) in enumerate(masks_and_titles):
    im = mask_axs[i].imshow(mask, cmap="gray", aspect='auto')
    mask_axs[i].set_title(title, fontsize=8)
    images.append(im)

# Add colorbar at the bottom
fig.subplots_adjust(bottom=0.2)  # Make space for colorbar
cbar_ax = fig.add_axes([0.15, 0.1, 0.7, 0.02])  # [left, bottom, width, height]
cbar = plt.colorbar(images[0], cax=cbar_ax, orientation='horizontal')
cbar.ax.set_xlabel('Mask Values', labelpad=5, fontsize=8)
cbar.set_ticks([0, 1])
cbar.set_ticklabels(['Attend (0)', 'Ignore/Mask (1)'])
cbar.ax.tick_params(labelsize=6)

plt.show()

# %% [markdown]
# ### Positional Encoding
# - Implement the `PositionalEncoding` class in `hw4lib/model/positional_encoding.py`.
# - Run the cell below to check your implementation.
# - You will need to make use of this positional encoding in both `HW4P1` and `HW4P2`.

# %%
# !python -m tests.test_positional_encoding

# %% [markdown]
# #### Optional: Visualize your Positional Encoding

# %%
# Create sample positional encoding
d_model = 64
max_len = 100
pos_encoding = PositionalEncoding(d_model=d_model, max_len=max_len)
pe = pos_encoding.pe.squeeze(0).numpy()  # Remove batch dimension and convert to numpy

# Create figure with two subplots side by side
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

# Plot 1: Positional encoding matrix
im = ax1.imshow(pe, aspect='auto', cmap='RdBu',
                extent=[0, d_model, max_len, 0])  # Flip y-axis to show position top-to-bottom
plt.colorbar(im, ax=ax1, label='Encoding Value')
ax1.set_xlabel('Dimension')
ax1.set_ylabel('Position')
ax1.set_title('Positional Encoding Matrix')
ax1.grid(False)

# Plot 2: Sinusoidal patterns
dimensions = [0, 15, 31, 47, 63]  # Plot first few dimensions
for dim in dimensions:
    ax2.plot(pe[:, dim], label=f'dim {dim}')
ax2.set_xlabel('Position')
ax2.set_ylabel('Encoding Value')
ax2.set_title('Sinusoidal Patterns for Different Dimensions')
ax2.legend()
ax2.grid(True)

# Adjust layout to prevent overlap
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Transformer Sublayers
# - Implement the Transformer Sublayers: `SelfAttentionLayer`, and `FeedForwardLayer` classes in `hw4lib/model/sublayers.py`.
# - Run the cell below to check your implementation.
# - You will need to make use of all of these sublayers in both `HW4P1` and `HW4P2`.

# %%
# !python -m tests.test_sublayer_selfattention

# %%
# !python -m tests.test_sublayer_feedforward

# %% [markdown]
# ### Transformer Self-Attention Decoder Layer
# - Implement the Transformer Layer: `SelfAttentionDecoderLayer` class in `hw4lib/model/decoder_layers.py`.
# - Run the cell below to check your implementation.
# - You will need to make use of this sublayer in `HW4P2`.

# %%
# !python -m tests.test_decoderlayer_selfattention

# %% [markdown]
# ### Decoder-Only Transformer
#
# - Implement the `DecoderOnlyTransformer` class in `hw4lib/model/transformers.py`.
# - Run the cell below to check your implementation.
# - You will need to make use of in `HW4P1` and optionally `HW4P2`.

# %%
# !python -m tests.test_transformer_decoder_only

# %% [markdown]
# ## Decoding Implementation
# - Implement the `generate_greedy` method of the `SequenceGenerator` class in `hw4lib/decoding/sequence_generator.py`.
# - Run the cell below to check your implementation.

# %%
# !python -m tests.test_decoding --mode greedy

# %% [markdown]
# ## Trainer Implementation
# You will have to do some minor in-filling for the `LMTrainer` class in `hw4lib/trainers/lm_trainer.py` before you can use it.
# - Fill in the `TODO`s in the `__init__`.
# - Fill in the `TODO`s in the `_train_epoch`.
# - Fill in the `TODO`s in the `_validate_epoch`.
# - Fill in the `TODO`s in the `generate` method.
# - Fill in the `TODO`s in the `train` method.
#
# `WARNING`: There are no test's for this. Implement carefully!

# %% [markdown]
# # Experiments
# From this point onwards you may want to switch to a `GPU` runtime.
# - `OBJECTIVE`: You must achieve a per-character perplexity ≤ 3.5 in order to get points for Task 2.

# %% [markdown]
# ## Config
# - You can use the `config.yaml` file to set your config for your ablation study.
#
# ---
# ### Notes:
#
# - Set `tokenization: token_type:` to specify your desired tokenization strategy
# - You will need to set the root path to your `hw4p1_data` folder in `data: root:`. This will depend on your setup. For eg. if you are following out setup instruction:
#   - `PSC`: `"/ocean/projects/cis250019p/mzhang23/TA/HW4/hw4p1_data"`
#   - `Colab:`: `"/content/hw4_data/hw4p1_data"`
#   - `Kaggle:`: `"/kaggle/input/s25-hw4-data/hw4p1_data"`
# - There's extra configurations in the `optimizer` section which will only be relevant if you decide to use the `create_optimizer` function we've provided in `hw4lib/utils/create_optimizer.py`.
# - `BE CAREFUL` while setting numeric values. Eg. `1e-4` will get serialized to a `str` while `1.0e-4` gets serialized to float.

# %%
# %%writefile config.yaml
#
# Name                      : "Siddarth Ashok"
#
# ###### Tokenization ------------------------------------------------------------
# tokenization:
#   token_type                : "5k"       # [char, 1k, 5k, 10k]
#   token_map :
#       'char': 'hw4lib/data/tokenizer_jsons/tokenizer_char.json'
#       '1k'  : 'hw4lib/data/tokenizer_jsons/tokenizer_1000.json'
#       '5k'  : 'hw4lib/data/tokenizer_jsons/tokenizer_5000.json'
#       '10k' : 'hw4lib/data/tokenizer_jsons/tokenizer_10000.json'
#
# ###### Dataset -----------------------------------------------------------------
# data:                    # Currently setup for Colab assuming out setup
#   root                 : "hw4_data/hw4p1_data"  # TODO: Set the root path of your data
#   train_partition      : "train"  # train
#   val_partition        : "val"    # val
#   test_partition       : "test"   # test
#   subset               : 1.0      # Load a subset of the data (for debugging, testing, etc
#   batch_size           : 256      #
#   NUM_WORKERS          : 2        # Set to 0 for CPU
#
# ###### Network Specs -------------------------------------------------------------
# model: # Decoder-Only Language Model (HW4P1)
#   d_model                   : 512
#   d_ff                      : 2048
#   num_layers                : 2
#   num_heads                 : 8
#   dropout                   : 0.05
#   layer_drop_rate           : 0.0
#   weight_tying              : True
#
# ###### Common Training Parameters ------------------------------------------------
# training:
#   use_wandb                   : True   # Toggle wandb logging
#   wandb_run_id                : "none" # "none" or "run_id"
#   resume                      : False  # Resume an existing run (run_id != 'none')
#   epochs                      : 50
#   gradient_accumulation_steps : 1
#   wandb_project               : "HW4P1" # wandb project to log to
#
# ###### Loss ----------------------------------------------------------------------
# loss: # Just good ol' CrossEntropy
#   label_smoothing: 0.0
#
# ###### Optimizer -----------------------------------------------------------------
# optimizer:
#   name: "adamw" # Options: sgd, adam, adamw
#   lr: 1.0e-3 # Base learning rate
#
#   # Common parameters
#   weight_decay: 0.0001
#
#   # Parameter groups
#   param_groups:
#     - name: self_attn
#       patterns: []  # Will match all parameters containing keywords set their learning rate to 0.0001
#       lr: 0.0001    # LR for self_attn
#       layer_decay:
#         enabled: False
#         decay_rate: 0.8
#
#     - name: ffn
#       patterns: [] # Will match all parameters containing "ffn" and set their learning rate to 0.0001
#       lr: 0.0001   # LR for ffn
#       layer_decay:
#         enabled: False
#         decay_rate: 0.8
#
#   # Layer-wise learning rates
#   layer_decay:
#     enabled: False
#     decay_rate: 0.75
#
#   # SGD specific parameters
#   sgd:
#     momentum: 0.9
#     nesterov: True
#     dampening: 0
#
#   # Adam specific parameters
#   adam:
#     betas: [0.9, 0.999]
#     eps: 1.0e-8
#     amsgrad: False
#
#   # AdamW specific parameters
#   adamw:
#     betas: [0.9, 0.999]
#     eps: 1.0e-8
#     amsgrad: False
#
# ###### Scheduler -----------------------------------------------------------------
# scheduler:
#   name: "reduce_lr"  # Options: reduce_lr, cosine, cosine_warm
#
#   # ReduceLROnPlateau specific parameters
#   reduce_lr:
#     mode: "min"  # Options: min, max
#     factor: 0.5  # Factor to reduce learning rate by
#     patience: 10  # Number of epochs with no improvement after which LR will be reduced
#     threshold: 0.0001  # Threshold for measuring the new optimum
#     threshold_mode: "rel"  # Options: rel, abs
#     cooldown: 0  # Number of epochs to wait before resuming normal operation
#     min_lr: 0.0000001  # Minimum learning rate
#     eps: 1.0e-8  # Minimal decay applied to lr
#
#   # CosineAnnealingLR specific parameters
#   cosine:
#     T_max: 48  # Maximum number of iterations
#     eta_min: 1.0e-8  # Minimum learning rate
#     last_epoch: -1
#
#   # CosineAnnealingWarmRestarts specific parameters
#   cosine_warm:
#     T_0: 5  # Number of iterations for the first restart
#     T_mult: 2  # Factor increasing T_i after each restart
#     eta_min: 0.0000001  # Minimum learning rate
#     last_epoch: -1
#
#   # Warmup parameters (can be used with any scheduler)
#   warmup:
#     enabled: False
#     type: "linear"  # Options: linear, exponential
#     epochs: 5
#     start_factor: 0.1
#     end_factor: 1.0
# Out:
# Overwriting config.yaml

# %%
with open('config.yaml', 'r') as file:
    config = yaml.safe_load(file)

# %% [markdown]
# ## Tokenizer

# %%
Tokenizer = H4Tokenizer(
    token_map  = config['tokenization']['token_map'],
    token_type = config['tokenization']['token_type']
)
# Out:
# ================================================================================
#                           Tokenizer Configuration (5k)
# --------------------------------------------------------------------------------
# Vocabulary size:     5000
#
# Special Tokens:
# PAD:              0
# UNK:              1
# MASK:             2
# SOS:              3
# EOS:              4
# BLANK:            5
#
# Validation Example:
# --------------------------------------------------------------------------------
# Input text:  [SOS]HI DEEP LEARNERS[EOS]
# Tokens:      ['[SOS]', 'H', 'I', 'ĠDEEP', 'ĠLEARN', 'ERS', '[EOS]']
# Token IDs:   [3, 14, 15, 1169, 2545, 214, 4]
# Decoded:     [SOS]HI DEEP LEARNERS[EOS]
# ================================================================================

# %% [markdown]
# ## Datasets

# %%
train_dataset  = LMDataset(
    partition  = config['data']['train_partition'],
    config     = config['data'],
    tokenizer  = Tokenizer
)

val_dataset    = LMDataset(
    partition  = config['data']['val_partition'],
    config     = config['data'],
    tokenizer  = Tokenizer
)

test_dataset   = LMDataset(
    partition  = config['data']['test_partition'],
    config     = config['data'],
    tokenizer  = Tokenizer
)

gc.collect()
# Out:
# Loading transcripts for train partition...
# 100%|██████████| 267/267 [00:01<00:00, 150.53it/s]
# Loading transcripts for val partition...
# 100%|██████████| 267/267 [00:00<00:00, 4450.16it/s]
# Loading transcripts for test partition...
# 100%|██████████| 267/267 [00:00<00:00, 4129.77it/s]
# 1168983

# %% [markdown]
# ## Dataloaders

# %%
train_loader    = DataLoader(
    dataset     = train_dataset,
    batch_size  = config['data']['batch_size'],
    shuffle     = True,
    num_workers = config['data']['NUM_WORKERS'] if device == 'cuda' else 0,
    pin_memory  = True,
    collate_fn  = train_dataset.collate_fn
)

val_loader      = DataLoader(
    dataset     = val_dataset,
    batch_size  = config['data']['batch_size'],
    shuffle     = False,
    num_workers = config['data']['NUM_WORKERS'] if device == 'cuda' else 0,
    pin_memory  = True,
    collate_fn  = val_dataset.collate_fn
)

test_loader     = DataLoader(
    dataset     = test_dataset,
    batch_size  = config['data']['batch_size'],
    shuffle     = False,
    num_workers = config['data']['NUM_WORKERS'] if device == 'cuda' else 0,
    pin_memory  = True,
    collate_fn  = test_dataset.collate_fn
)

# %% [markdown]
# ### Dataloader Verification

# %%
verify_dataloader(train_loader)
# Out:
# ==================================================
#              Dataloader Verification
# ==================================================
# Dataloader Partition     : train
# --------------------------------------------------
# Number of Batches        : 2
# Batch Size               : 256
# --------------------------------------------------
# Checking shapes of the data...
#
# Shifted Transcript Shape : [256, 70]
# Golden Transcript Shape  : [256, 70]
# Transcript Lengths Shape : [256]
# --------------------------------------------------
# Max Transcript Length    : 70
# Avg. Chars per Token     : 4.14
# ==================================================

# %%
verify_dataloader(val_loader)
# Out:
# ==================================================
#              Dataloader Verification
# ==================================================
# Dataloader Partition     : val
# --------------------------------------------------
# Number of Batches        : 2
# Batch Size               : 256
# --------------------------------------------------
# Checking shapes of the data...
#
# Shifted Transcript Shape : [256, 70]
# Golden Transcript Shape  : [256, 70]
# Transcript Lengths Shape : [256]
# --------------------------------------------------
# Max Transcript Length    : 70
# Avg. Chars per Token     : 4.14
# ==================================================

# %%
verify_dataloader(test_loader)
# Out:
# ==================================================
#              Dataloader Verification
# ==================================================
# Dataloader Partition     : test
# --------------------------------------------------
# Number of Batches        : 2
# Batch Size               : 256
# --------------------------------------------------
# Checking shapes of the data...
#
# Shifted Transcript Shape : [256, 70]
# Golden Transcript Shape  : [256, 70]
# Transcript Lengths Shape : [256]
# --------------------------------------------------
# Max Transcript Length    : 70
# Avg. Chars per Token     : 4.14
# ==================================================

# %% [markdown]
# ## Calculate Max Transcript Length

# %% [markdown]
# Calculating the maximum transcript length across your dataset is a crucial step when working with certain transformer models.
# -  We'll use sinusoidal positional encodings that must be precomputed up to a fixed maximum length.
# - This maximum length is a hyperparameter that determines:
#   - How long of a sequence your model can process
#   - The size of your positional encoding matrix
#   - Memory requirements during training and inference
# - `Requirements`: For this assignment, ensure your positional encodings can accommodate at least the longest sequence in your dataset to prevent truncation. However, you can set this value higher if you anticipate using your language model to work with longer sequences in future tasks (hint: this might be useful for P2! 😉).

# %%
#max_transcript_length = max(train_dataset.text_max_len, val_dataset.text_max_len, test_dataset.text_max_len)
max_transcript_length = 260
print("="*50)
print(f"{'Global Max Transcript Length':<30} : {max_transcript_length}")
print("="*50)
# Out:
# ==================================================
# Global Max Transcript Length   : 260
# ==================================================

# %% [markdown]
# ## Model

# %%
model_config = config['model']
model_config.update({
    'max_len': max_transcript_length,
    'num_classes': Tokenizer.vocab_size
})
model = DecoderOnlyTransformer(**model_config)

# Get some inputs from the text loader
for batch in train_loader:
    shifted_transcripts, golden_transcripts, transcript_lengths = batch
    print("Shape of shifted_transcripts : ", shifted_transcripts.shape)
    print("Shape of golden_transcripts  : ", golden_transcripts.shape)
    print("Shape of transcript_lengths  : ", transcript_lengths.shape)
    break
model.to(device)
shifted_transcripts = shifted_transcripts.to(device)
transcript_lengths = transcript_lengths.to(device)
golden_transcripts = golden_transcripts.to(device)
model_stats = summary(model, input_data=[shifted_transcripts, transcript_lengths], device=device)
print(model_stats)
# Out:
# Shape of shifted_transcripts :  torch.Size([256, 70])
# Shape of golden_transcripts  :  torch.Size([256, 70])
# Shape of transcript_lengths  :  torch.Size([256])
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# DecoderOnlyTransformer                        [256, 70, 5000]           --
# ├─Embedding: 1-1                              [256, 70, 512]            2,560,000
# ├─PositionalEncoding: 1-2                     [256, 70, 512]            --
# ├─Dropout: 1-3                                [256, 70, 512]            --
# ├─ModuleList: 1-4                             --                        --
# │    └─SelfAttentionDecoderLayer: 2-1         [256, 70, 512]            --
# │    │    └─SelfAttentionLayer: 3-1           [256, 70, 512]            1,051,648
# │    │    └─FeedForwardLayer: 3-2             [256, 70, 512]            2,100,736
# │    └─SelfAttentionDecoderLayer: 2-2         [256, 70, 512]            --
# │    │    └─SelfAttentionLayer: 3-3           [256, 70, 512]            1,051,648
# │    │    └─FeedForwardLayer: 3-4             [256, 70, 512]            2,100,736
# ├─LayerNorm: 1-5                              [256, 70, 512]            1,024
# ├─Linear: 1-6                                 [256, 70, 5000]           2,565,000
# ===============================================================================================
# Total params: 11,430,792
# Trainable params: 11,430,792
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 2.39
# ===============================================================================================
# Input size (MB): 0.15
# Forward/backward pass size (MB): 1891.21
# Params size (MB): 37.32
# Estimated Total Size (MB): 1928.67
# ===============================================================================================

# %% [markdown]
# ## Wandb

# %%
wandb.login(key="cf6d7f096f22962de03aa3fb7237fc654bfe1350")
# Out:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: C:\Users\sidas\_netrc
# True

# %% [markdown]
# ## Trainer
#
# Every time you run the trainer, it will create a new directory in the `expts` folder with the following structure:
# ```
# expts/
#     └── {run_name}/
#         ├── config.yaml
#         ├── model_arch.txt
#         ├── checkpoints/
#         │   ├── checkpoint-best-metric-model.pth
#         │   └── checkpoint-last-epoch-model.pth
#         ├── attn/
#         │   └── {attention visualizations}
#         └── text/
#             └── {generated text outputs}
# ```

# %%
trainer = LMTrainer(
    model=model,
    tokenizer=Tokenizer,
    config=config,
    run_name="test-lm",
    config_file="config.yaml",
    device=device
)
# Out:
# Using device: cuda
# Tracking run with wandb version 0.19.2
# Run data is saved locally in <code>c:\Users\sidas\OneDrive\Documents\GitHub\Introduction-to-Deep-Learning-11785-Homeworks\HW4\IDL-HW4\wandb\run-20251111_201701-so9wjy3c</code>
# Syncing run <strong><a href='https://wandb.ai/sashok2-carnegie-mellon-university/HW4P1/runs/so9wjy3c' target="_blank">test-lm</a></strong> to <a href='https://wandb.ai/sashok2-carnegie-mellon-university/HW4P1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sashok2-carnegie-mellon-university/HW4P1' target="_blank">https://wandb.ai/sashok2-carnegie-mellon-university/HW4P1</a>
#  View run at <a href='https://wandb.ai/sashok2-carnegie-mellon-university/HW4P1/runs/so9wjy3c' target="_blank">https://wandb.ai/sashok2-carnegie-mellon-university/HW4P1/runs/so9wjy3c</a>

# %% [markdown]
# ### Setup Optimizer and Scheduler
#
# You can set your own optimizer and scheduler by setting the class members in the `LMTrainer` class.
# Eg:
# ```python
# trainer.optimizer = optim.AdamW(model.parameters(), lr=config['optimizer']['lr'], weight_decay=config['optimizer']['weight_decay'])
# trainer.scheduler = optim.lr_scheduler.CosineAnnealingLR(trainer.optimizer, T_max=config['training']['epochs'])
# ```
#
# We also provide a utility function to create your own optimizer and scheduler with the congig and some extra bells and whistles. You are free to use it or not. Do read their code and documentation to understand how it works (`hw4lib/utils/*`).

# %% [markdown]
# #### Setting up the optimizer

# %%
trainer.optimizer = create_optimizer(
    model=model,
    opt_config=config['optimizer']
)
# Out:
# 🔧 Configuring Optimizer:
# ├── Type: ADAMW
# ├── Base LR: 0.001
# ├── Weight Decay: 0.0001
# ├── Parameter Groups:
# │   ├── Group: self_attn
# │   │   ├── LR: 0.0001
# │   │   └── Patterns: []
# │   ├── Group: ffn
# │   │   ├── LR: 0.0001
# │   │   └── Patterns: []
# │   └── Default Group (unmatched parameters)
# └── AdamW Specific:
#     ├── Betas: [0.9, 0.999]
#     ├── Epsilon: 1e-08
#     └── AMSGrad: False

# %% [markdown]
# #### Creating a test scheduler and plotting the learning rate schedule

# %%
test_scheduler = create_scheduler(
    optimizer=trainer.optimizer,
    scheduler_config=config['scheduler'],
    train_loader=train_loader,
    gradient_accumulation_steps=config['training']['gradient_accumulation_steps']
)

plot_lr_schedule(
    scheduler=test_scheduler,
    num_epochs=config['training']['epochs'],
    train_loader=train_loader,
    gradient_accumulation_steps=config['training']['gradient_accumulation_steps']
)
# Out:
# 📈 Configuring Learning Rate Scheduler:
# ├── Type: REDUCE_LR
# ├── ReduceLROnPlateau Settings:
# │   ├── Mode: min
# │   ├── Factor: 0.5
# │   ├── Patience: 10 epochs
# │   ├── Threshold: 0.0001
# │   ├── Threshold Mode: rel
# │   ├── Cooldown: 0 epochs
# │   └── Min LR: 1e-07
# Warning: Only showing 5 out of 28 parameter groups for clarity

# %% [markdown]
# #### Setting up the scheduler

# %%
trainer.scheduler = create_scheduler(
    optimizer=trainer.optimizer,
    scheduler_config=config['scheduler'],
    train_loader=train_loader,
    gradient_accumulation_steps=config['training']['gradient_accumulation_steps']
)
# Out:
# 📈 Configuring Learning Rate Scheduler:
# ├── Type: REDUCE_LR
# ├── ReduceLROnPlateau Settings:
# │   ├── Mode: min
# │   ├── Factor: 0.5
# │   ├── Patience: 10 epochs
# │   ├── Threshold: 0.0001
# │   ├── Threshold Mode: rel
# │   ├── Cooldown: 0 epochs
# │   └── Min LR: 1e-07

# %%
checkpoint = torch.load("checkpoint-last-epoch-model.pth")
model.load_state_dict(checkpoint["model_state_dict"])
trainer.optimizer.load_state_dict(checkpoint["optimizer_state_dict"])
trainer.scheduler.load_state_dict(checkpoint["scheduler_state_dict"])
start_epoch = checkpoint["epoch"] + 1

# %%
import gc
gc.collect()
# with torch.no_grad():
#     torch.cuda.empty_cache()
# Out:
# 969144

# %%
torch.save(model.state_dict(), "best.pth")

# %% [markdown]
# # Train
# - Set your epochs

# %%
trainer.train(train_loader, val_loader, epochs=config['training']['epochs'])
# Out:
# Generating with greedy search...
#
# 📊 Metrics (Epoch 0):
# ├── TRAIN:
# │   ├── ce_loss_char: 1.2763
# │   ├── ce_loss_token: 5.2809
# │   ├── perplexity_char: 3.5832
# │   └── perplexity_token: 196.5370
# └── VAL:
#     ├── ce_loss_char: 1.2689
#     ├── ce_loss_token: 5.2504
#     ├── perplexity_char: 3.5569
#     └── perplexity_token: 190.6341
# └── TRAINING:
#     └── learning_rate: 0.001000
# Generating with greedy search...
#
# 📊 Metrics (Epoch 1):
# ├── TRAIN:
# │   ├── ce_loss_char: 1.2722
# │   ├── ce_loss_token: 5.2643
# │   ├── perplexity_char: 3.5689
# │   └── perplexity_token: 193.3047
# └── VAL:
#     ├── ce_loss_char: 1.2682
#     ├── ce_loss_token: 5.2476
#     ├── perplexity_char: 3.5545
#     └── perplexity_token: 190.1030
# └── TRAINING:
#     └── learning_rate: 0.001000
# Generating with greedy search...
#
# 📊 Metrics (Epoch 2):
# ├── TRAIN:
# │   ├── ce_loss_char: 1.2714
# │   ├── ce_loss_token: 5.2608
# │   ├── perplexity_char: 3.5659
# │   └── perplexity_token: 192.6436
# └── VAL:
#     ├── ce_loss_char: 1.2661
#     ├── ce_loss_token: 5.2388
#     ├── perplexity_char: 3.5469
#     └── perplexity_token: 188.4360
# └── TRAINING:
#     └── learning_rate: 0.001000
# Generating with greedy search...
#
# 📊 Metrics (Epoch 3):
# ├── TRAIN:
# │   ├── ce_loss_char: 1.2692
# │   ├── ce_loss_token: 5.2515
# │   ├── perplexity_char: 3.5579
# │   └── perplexity_token: 190.8497
# └── VAL:
#     ├── ce_loss_char: 1.2644
#     ├── ce_loss_token: 5.2318
#     ├── perplexity_char: 3.5410
#     └── perplexity_token: 187.1365
# └── TRAINING:
#     └── learning_rate: 0.001000
# Generating with greedy search...
#
# 📊 Metrics (Epoch 4):
# ├── TRAIN:
# │   ├── ce_loss_char: 1.2681
# │   ├── ce_loss_token: 5.2470
# │   ├── perplexity_char: 3.5540
# │   └── perplexity_token: 189.9984
# └── VAL:
#     ├── ce_loss_char: 1.2646
#     ├── ce_loss_token: 5.2325
#     ├── perplexity_char: 3.5416
#     └── perplexity_token: 187.2693
# └── TRAINING:
#     └── learning_rate: 0.001000
# Generating with greedy search...
#
# 📊 Metrics (Epoch 5):
# ├── TRAIN:
# │   ├── ce_loss_char: 1.2686
# │   ├── ce_loss_token: 5.2493
# │   ├── perplexity_char: 3.5559
# │   └── perplexity_token: 190.4269
# └── VAL:
#     ├── ce_loss_char: 1.2634
#     ├── ce_loss_token: 5.2278
#     ├── perplexity_char: 3.5376
#     └── perplexity_token: 186.3870
# └── TRAINING:
#     └── learning_rate: 0.001000
# Generating with greedy search...
#
# 📊 Metrics (Epoch 6):
# ├── TRAIN:
# │   ├── ce_loss_char: 1.2658
# │   ├── ce_loss_token: 5.2377
# │   ├── perplexity_char: 3.5460
# │   └── perplexity_token: 188.2437
# └── VAL:
#     ├── ce_loss_char: 1.2621
#     ├── ce_loss_token: 5.2225
#     ├── perplexity_char: 3.5330
#     └── perplexity_token: 185.3918
# └── TRAINING:
#     └── learning_rate: 0.001000
# Generating with greedy search...
#
# 📊 Metrics (Epoch 7):
# ├── TRAIN:
# │   ├── ce_loss_char: 1.2658
# │   ├── ce_loss_token: 5.2375
# │   ├── perplexity_char: 3.5459
# │   └── perplexity_token: 188.2062
# └── VAL:
#     ├── ce_loss_char: 1.2626
#     ├── ce_loss_token: 5.2242
#     ├── perplexity_char: 3.5345
#     └── perplexity_token: 185.7100
# └── TRAINING:
#     └── learning_rate: 0.001000
# Generating with greedy search...
#
# 📊 Metrics (Epoch 8):
# ├── TRAIN:
# │   ├── ce_loss_char: 1.2655
# │   ├── ce_loss_token: 5.2364
# │   ├── perplexity_char: 3.5449
# │   └── perplexity_token: 187.9993
# └── VAL:
#     ├── ce_loss_char: 1.2622
#     ├── ce_loss_token: 5.2228
#     ├── perplexity_char: 3.5332
#     └── perplexity_token: 185.4469
# └── TRAINING:
#     └── learning_rate: 0.001000
# Generating with greedy search...
#
# 📊 Metrics (Epoch 9):
# ├── TRAIN:
# │   ├── ce_loss_char: 1.2658
# │   ├── ce_loss_token: 5.2375
# │   ├── perplexity_char: 3.5459
# │   └── perplexity_token: 188.2044
# └── VAL:
#     ├── ce_loss_char: 1.2619
#     ├── ce_loss_token: 5.2214
#     ├── perplexity_char: 3.5321
#     └── perplexity_token: 185.2019
# └── TRAINING:
#     └── learning_rate: 0.001000
# Generating with greedy search...
#
# 📊 Metrics (Epoch 10):
# ├── TRAIN:
# │   ├── ce_loss_char: 1.2661
# │   ├── ce_loss_token: 5.2390
# │   ├── perplexity_char: 3.5472
# │   └── perplexity_token: 188.4880
# └── VAL:
#     ├── ce_loss_char: 1.2603
#     ├── ce_loss_token: 5.2149
#     ├── perplexity_char: 3.5265
#     └── perplexity_token: 183.9964
# └── TRAINING:
#     └── learning_rate: 0.001000
# Generating with greedy search...
#
# 📊 Metrics (Epoch 11):
# ├── TRAIN:
# │   ├── ce_loss_char: 1.2634
# │   ├── ce_loss_token: 5.2277
# │   ├── perplexity_char: 3.5375
# │   └── perplexity_token: 186.3687
# └── VAL:
#     ├── ce_loss_char: 1.2580
#     ├── ce_loss_token: 5.2055
#     ├── perplexity_char: 3.5185
#     └── perplexity_token: 182.2727
# └── TRAINING:
#     └── learning_rate: 0.001000
# Generating with greedy search...
#
# 📊 Metrics (Epoch 12):
# ├── TRAIN:
# │   ├── ce_loss_char: 1.2621
# │   ├── ce_loss_token: 5.2223
# │   ├── perplexity_char: 3.5328
# │   └── perplexity_token: 185.3560
# └── VAL:
#     ├── ce_loss_char: 1.2570
#     ├── ce_loss_token: 5.2014
#     ├── perplexity_char: 3.5150
#     └── perplexity_token: 181.5205
# └── TRAINING:
#     └── learning_rate: 0.001000
# Generating with greedy search...
#
# 📊 Metrics (Epoch 13):
# ├── TRAIN:
# │   ├── ce_loss_char: 1.2611
# │   ├── ce_loss_token: 5.2181
# │   ├── perplexity_char: 3.5293
# │   └── perplexity_token: 184.5859
# └── VAL:
#     ├── ce_loss_char: 1.2574
#     ├── ce_loss_token: 5.2029
#     ├── perplexity_char: 3.5164
#     └── perplexity_token: 181.8072
# └── TRAINING:
#     └── learning_rate: 0.001000
# Generating with greedy search...
#
# 📊 Metrics (Epoch 14):
# ├── TRAIN:
# │   ├── ce_loss_char: 1.2620
# │   ├── ce_loss_token: 5.2217
# │   ├── perplexity_char: 3.5324
# │   └── perplexity_token: 185.2555
# └── VAL:
#     ├── ce_loss_char: 1.2576
#     ├── ce_loss_token: 5.2036
#     ├── perplexity_char: 3.5169
#     └── perplexity_token: 181.9197
# └── TRAINING:
#     └── learning_rate: 0.001000
# Generating with greedy search...
#
# 📊 Metrics (Epoch 15):
# ├── TRAIN:
# │   ├── ce_loss_char: 1.2612
# │   ├── ce_loss_token: 5.2187
# │   ├── perplexity_char: 3.5298
# │   └── perplexity_token: 184.7029
# └── VAL:
#     ├── ce_loss_char: 1.2583
#     ├── ce_loss_token: 5.2066
#     ├── perplexity_char: 3.5195
#     └── perplexity_token: 182.4815
# └── TRAINING:
#     └── learning_rate: 0.001000
# Generating with greedy search...
#
# 📊 Metrics (Epoch 16):
# ├── TRAIN:
# │   ├── ce_loss_char: 1.2617
# │   ├── ce_loss_token: 5.2206
# │   ├── perplexity_char: 3.5314
# │   └── perplexity_token: 185.0526
# └── VAL:
#     ├── ce_loss_char: 1.2578
#     ├── ce_loss_token: 5.2043
#     ├── perplexity_char: 3.5175
#     └── perplexity_token: 182.0606
# └── TRAINING:
#     └── learning_rate: 0.001000
# Generating with greedy search...
#
# 📊 Metrics (Epoch 17):
# ├── TRAIN:
# │   ├── ce_loss_char: 1.2617
# │   ├── ce_loss_token: 5.2205
# │   ├── perplexity_char: 3.5313
# │   └── perplexity_token: 185.0298
# └── VAL:
#     ├── ce_loss_char: 1.2582
#     ├── ce_loss_token: 5.2062
#     ├── perplexity_char: 3.5191
#     └── perplexity_token: 182.4050
# └── TRAINING:
#     └── learning_rate: 0.001000
# Generating with greedy search...
#
# 📊 Metrics (Epoch 18):
# ├── TRAIN:
# │   ├── ce_loss_char: 1.2612
# │   ├── ce_loss_token: 5.2188
# │   ├── perplexity_char: 3.5298
# │   └── perplexity_token: 184.7033
# └── VAL:
#     ├── ce_loss_char: 1.2580
#     ├── ce_loss_token: 5.2052
#     ├── perplexity_char: 3.5183
#     └── perplexity_token: 182.2213
# └── TRAINING:
#     └── learning_rate: 0.001000
# Generating with greedy search...
#
# 📊 Metrics (Epoch 19):
# ├── TRAIN:
# │   ├── ce_loss_char: 1.2614
# │   ├── ce_loss_token: 5.2193
# │   ├── perplexity_char: 3.5303
# │   └── perplexity_token: 184.8077
# └── VAL:
#     ├── ce_loss_char: 1.2595
#     ├── ce_loss_token: 5.2116
#     ├── perplexity_char: 3.5237
#     └── perplexity_token: 183.3872
# └── TRAINING:
#     └── learning_rate: 0.001000
# Generating with greedy search...
#
# 📊 Metrics (Epoch 20):
# ├── TRAIN:
# │   ├── ce_loss_char: 1.2631
# │   ├── ce_loss_token: 5.2265
# │   ├── perplexity_char: 3.5365
# │   └── perplexity_token: 186.1475
# └── VAL:
#     ├── ce_loss_char: 1.2592
#     ├── ce_loss_token: 5.2105
#     ├── perplexity_char: 3.5228
#     └── perplexity_token: 183.1847
# └── TRAINING:
#     └── learning_rate: 0.001000
# Generating with greedy search...
#
# 📊 Metrics (Epoch 21):
# ├── TRAIN:
# │   ├── ce_loss_char: 1.2627
# │   ├── ce_loss_token: 5.2247
# │   ├── perplexity_char: 3.5349
# │   └── perplexity_token: 185.7995
# └── VAL:
#     ├── ce_loss_char: 1.2600
#     ├── ce_loss_token: 5.2136
#     ├── perplexity_char: 3.5254
#     └── perplexity_token: 183.7469
# └── TRAINING:
#     └── learning_rate: 0.001000
# Generating with greedy search...
#
# 📊 Metrics (Epoch 22):
# ├── TRAIN:
# │   ├── ce_loss_char: 1.2646
# │   ├── ce_loss_token: 5.2327
# │   ├── perplexity_char: 3.5417
# │   └── perplexity_token: 187.2952
# └── VAL:
#     ├── ce_loss_char: 1.2577
#     ├── ce_loss_token: 5.2041
#     ├── perplexity_char: 3.5174
#     └── perplexity_token: 182.0215
# └── TRAINING:
#     └── learning_rate: 0.001000
# Generating with greedy search...
#
# 📊 Metrics (Epoch 23):
# ├── TRAIN:
# │   ├── ce_loss_char: 1.2610
# │   ├── ce_loss_token: 5.2179
# │   ├── perplexity_char: 3.5291
# │   └── perplexity_token: 184.5384
# └── VAL:
#     ├── ce_loss_char: 1.2553
#     ├── ce_loss_token: 5.1943
#     ├── perplexity_char: 3.5090
#     └── perplexity_token: 180.2348
# └── TRAINING:
#     └── learning_rate: 0.001000
# Generating with greedy search...
#
# 📊 Metrics (Epoch 24):
# ├── TRAIN:
# │   ├── ce_loss_char: 1.2592
# │   ├── ce_loss_token: 5.2101
# │   ├── perplexity_char: 3.5225
# │   └── perplexity_token: 183.1155
# └── VAL:
#     ├── ce_loss_char: 1.2552
#     ├── ce_loss_token: 5.1936
#     ├── perplexity_char: 3.5085
#     └── perplexity_token: 180.1236
# └── TRAINING:
#     └── learning_rate: 0.001000
# Generating with greedy search...
#
# 📊 Metrics (Epoch 25):
# ├── TRAIN:
# │   ├── ce_loss_char: 1.2581
# │   ├── ce_loss_token: 5.2056
# │   ├── perplexity_char: 3.5186
# │   └── perplexity_token: 182.2925
# └── VAL:
#     ├── ce_loss_char: 1.2516
#     ├── ce_loss_token: 5.1787
#     ├── perplexity_char: 3.4958
#     └── perplexity_token: 177.4505
# └── TRAINING:
#     └── learning_rate: 0.001000
# Generating with greedy search...
#
# 📊 Metrics (Epoch 26):
# ├── TRAIN:
# │   ├── ce_loss_char: 1.2559
# │   ├── ce_loss_token: 5.1965
# │   ├── perplexity_char: 3.5109
# │   └── perplexity_token: 180.6339
# └── VAL:
#     ├── ce_loss_char: 1.2496
#     ├── ce_loss_token: 5.1708
#     ├── perplexity_char: 3.4891
#     └── perplexity_token: 176.0492
# └── TRAINING:
#     └── learning_rate: 0.001000
# Generating with greedy search...
#
# 📊 Metrics (Epoch 27):
# ├── TRAIN:
# │   ├── ce_loss_char: 1.2543
# │   ├── ce_loss_token: 5.1899
# │   ├── perplexity_char: 3.5053
# │   └── perplexity_token: 179.4515
# └── VAL:
#     ├── ce_loss_char: 1.2465
#     ├── ce_loss_token: 5.1579
#     ├── perplexity_char: 3.4783
#     └── perplexity_token: 173.7929
# └── TRAINING:
#     └── learning_rate: 0.001000
# Generating with greedy search...
#
# 📊 Metrics (Epoch 28):
# ├── TRAIN:
# │   ├── ce_loss_char: 1.2507
# │   ├── ce_loss_token: 5.1752
# │   ├── perplexity_char: 3.4929
# │   └── perplexity_token: 176.8340
# └── VAL:
#     ├── ce_loss_char: 1.2450
#     ├── ce_loss_token: 5.1514
#     ├── perplexity_char: 3.4728
#     └── perplexity_token: 172.6706
# └── TRAINING:
#     └── learning_rate: 0.001000
# Generating with greedy search...
#
# 📊 Metrics (Epoch 29):
# ├── TRAIN:
# │   ├── ce_loss_char: 1.2490
# │   ├── ce_loss_token: 5.1681
# │   ├── perplexity_char: 3.4869
# │   └── perplexity_token: 175.5800
# └── VAL:
#     ├── ce_loss_char: 1.2452
#     ├── ce_loss_token: 5.1523
#     ├── perplexity_char: 3.4735
#     └── perplexity_token: 172.8220
# └── TRAINING:
#     └── learning_rate: 0.001000
# Generating with greedy search...
#
# 📊 Metrics (Epoch 30):
# ├── TRAIN:
# │   ├── ce_loss_char: 1.2494
# │   ├── ce_loss_token: 5.1697
# │   ├── perplexity_char: 3.4882
# │   └── perplexity_token: 175.8618
# └── VAL:
#     ├── ce_loss_char: 1.2489
#     ├── ce_loss_token: 5.1677
#     ├── perplexity_char: 3.4865
#     └── perplexity_token: 175.5062
# └── TRAINING:
#     └── learning_rate: 0.001000
# Generating with greedy search...
#
# 📊 Metrics (Epoch 31):
# ├── TRAIN:
# │   ├── ce_loss_char: 1.2526
# │   ├── ce_loss_token: 5.1831
# │   ├── perplexity_char: 3.4995
# │   └── perplexity_token: 178.2261
# └── VAL:
#     ├── ce_loss_char: 1.2504
#     ├── ce_loss_token: 5.1741
#     ├── perplexity_char: 3.4919
#     └── perplexity_token: 176.6333
# └── TRAINING:
#     └── learning_rate: 0.001000
# Generating with greedy search...
#
# 📊 Metrics (Epoch 32):
# ├── TRAIN:
# │   ├── ce_loss_char: 1.2545
# │   ├── ce_loss_token: 5.1908
# │   ├── perplexity_char: 3.5061
# │   └── perplexity_token: 179.6164
# └── VAL:
#     ├── ce_loss_char: 1.2493
#     ├── ce_loss_token: 5.1694
#     ├── perplexity_char: 3.4879
#     └── perplexity_token: 175.8052
# └── TRAINING:
#     └── learning_rate: 0.001000
# Generating with greedy search...
#
# 📊 Metrics (Epoch 33):
# ├── TRAIN:
# │   ├── ce_loss_char: 1.2527
# │   ├── ce_loss_token: 5.1835
# │   ├── perplexity_char: 3.4999
# │   └── perplexity_token: 178.3100
# └── VAL:
#     ├── ce_loss_char: 1.2459
#     ├── ce_loss_token: 5.1555
#     ├── perplexity_char: 3.4762
#     └── perplexity_token: 173.3744
# └── TRAINING:
#     └── learning_rate: 0.001000
# Generating with greedy search...
#
# 📊 Metrics (Epoch 34):
# ├── TRAIN:
# │   ├── ce_loss_char: 1.2501
# │   ├── ce_loss_token: 5.1725
# │   ├── perplexity_char: 3.4906
# │   └── perplexity_token: 176.3620
# └── VAL:
#     ├── ce_loss_char: 1.2446
#     ├── ce_loss_token: 5.1498
#     ├── perplexity_char: 3.4715
#     └── perplexity_token: 172.4050
# └── TRAINING:
#     └── learning_rate: 0.001000
# Generating with greedy search...
#
# 📊 Metrics (Epoch 35):
# ├── TRAIN:
# │   ├── ce_loss_char: 1.2491
# │   ├── ce_loss_token: 5.1684
# │   ├── perplexity_char: 3.4871
# │   └── perplexity_token: 175.6265
# └── VAL:
#     ├── ce_loss_char: 1.2427
#     ├── ce_loss_token: 5.1422
#     ├── perplexity_char: 3.4651
#     └── perplexity_token: 171.0858
# └── TRAINING:
#     └── learning_rate: 0.001000
# Generating with greedy search...
#
# 📊 Metrics (Epoch 36):
# ├── TRAIN:
# │   ├── ce_loss_char: 1.2466
# │   ├── ce_loss_token: 5.1580
# │   ├── perplexity_char: 3.4783
# │   └── perplexity_token: 173.8103
# └── VAL:
#     ├── ce_loss_char: 1.2443
#     ├── ce_loss_token: 5.1487
#     ├── perplexity_char: 3.4706
#     └── perplexity_token: 172.2092
# └── TRAINING:
#     └── learning_rate: 0.001000
# Generating with greedy search...
#
# 📊 Metrics (Epoch 37):
# ├── TRAIN:
# │   ├── ce_loss_char: 1.2488
# │   ├── ce_loss_token: 5.1673
# │   ├── perplexity_char: 3.4862
# │   └── perplexity_token: 175.4319
# └── VAL:
#     ├── ce_loss_char: 1.2435
#     ├── ce_loss_token: 5.1453
#     ├── perplexity_char: 3.4677
#     └── perplexity_token: 171.6278
# └── TRAINING:
#     └── learning_rate: 0.001000
# Generating with greedy search...
#
# 📊 Metrics (Epoch 38):
# ├── TRAIN:
# │   ├── ce_loss_char: 1.2482
# │   ├── ce_loss_token: 5.1647
# │   ├── perplexity_char: 3.4840
# │   └── perplexity_token: 174.9791
# └── VAL:
#     ├── ce_loss_char: 1.2433
#     ├── ce_loss_token: 5.1445
#     ├── perplexity_char: 3.4670
#     └── perplexity_token: 171.4877
# └── TRAINING:
#     └── learning_rate: 0.001000
# Generating with greedy search...
#
# 📊 Metrics (Epoch 39):
# ├── TRAIN:
# │   ├── ce_loss_char: 1.2470
# │   ├── ce_loss_token: 5.1598
# │   ├── perplexity_char: 3.4799
# │   └── perplexity_token: 174.1259
# └── VAL:
#     ├── ce_loss_char: 1.2415
#     ├── ce_loss_token: 5.1372
#     ├── perplexity_char: 3.4609
#     └── perplexity_token: 170.2312
# └── TRAINING:
#     └── learning_rate: 0.001000
# Generating with greedy search...
#
# 📊 Metrics (Epoch 40):
# ├── TRAIN:
# │   ├── ce_loss_char: 1.2461
# │   ├── ce_loss_token: 5.1562
# │   ├── perplexity_char: 3.4769
# │   └── perplexity_token: 173.5092
# └── VAL:
#     ├── ce_loss_char: 1.2417
#     ├── ce_loss_token: 5.1380
#     ├── perplexity_char: 3.4616
#     └── perplexity_token: 170.3741
# └── TRAINING:
#     └── learning_rate: 0.001000
# Generating with greedy search...
#
# 📊 Metrics (Epoch 41):
# ├── TRAIN:
# │   ├── ce_loss_char: 1.2457
# │   ├── ce_loss_token: 5.1542
# │   ├── perplexity_char: 3.4752
# │   └── perplexity_token: 173.1612
# └── VAL:
#     ├── ce_loss_char: 1.2395
#     ├── ce_loss_token: 5.1288
#     ├── perplexity_char: 3.4539
#     └── perplexity_token: 168.8142
# └── TRAINING:
#     └── learning_rate: 0.001000
# Generating with greedy search...
#
# 📊 Metrics (Epoch 42):
# ├── TRAIN:
# │   ├── ce_loss_char: 1.2431
# │   ├── ce_loss_token: 5.1437
# │   ├── perplexity_char: 3.4664
# │   └── perplexity_token: 171.3488
# └── VAL:
#     ├── ce_loss_char: 1.2397
#     ├── ce_loss_token: 5.1294
#     ├── perplexity_char: 3.4544
#     └── perplexity_token: 168.9176
# └── TRAINING:
#     └── learning_rate: 0.001000
# Generating with greedy search...
#
# 📊 Metrics (Epoch 43):
# ├── TRAIN:
# │   ├── ce_loss_char: 1.2438
# │   ├── ce_loss_token: 5.1467
# │   ├── perplexity_char: 3.4689
# │   └── perplexity_token: 171.8636
# └── VAL:
#     ├── ce_loss_char: 1.2378
#     ├── ce_loss_token: 5.1217
#     ├── perplexity_char: 3.4480
#     └── perplexity_token: 167.6281
# └── TRAINING:
#     └── learning_rate: 0.001000
# Generating with greedy search...
#
# 📊 Metrics (Epoch 44):
# ├── TRAIN:
# │   ├── ce_loss_char: 1.2418
# │   ├── ce_loss_token: 5.1382
# │   ├── perplexity_char: 3.4618
# │   └── perplexity_token: 170.4124
# └── VAL:
#     ├── ce_loss_char: 1.2350
#     ├── ce_loss_token: 5.1100
#     ├── perplexity_char: 3.4383
#     └── perplexity_token: 165.6727
# └── TRAINING:
#     └── learning_rate: 0.001000
# Generating with greedy search...
#
# 📊 Metrics (Epoch 45):
# ├── TRAIN:
# │   ├── ce_loss_char: 1.2393
# │   ├── ce_loss_token: 5.1278
# │   ├── perplexity_char: 3.4531
# │   └── perplexity_token: 168.6463
# └── VAL:
#     ├── ce_loss_char: 1.2356
#     ├── ce_loss_token: 5.1127
#     ├── perplexity_char: 3.4405
#     └── perplexity_token: 166.1266
# └── TRAINING:
#     └── learning_rate: 0.001000
# Generating with greedy search...
#
# 📊 Metrics (Epoch 46):
# ├── TRAIN:
# │   ├── ce_loss_char: 1.2400
# │   ├── ce_loss_token: 5.1309
# │   ├── perplexity_char: 3.4557
# │   └── perplexity_token: 169.1723
# └── VAL:
#     ├── ce_loss_char: 1.2376
#     ├── ce_loss_token: 5.1209
#     ├── perplexity_char: 3.4474
#     └── perplexity_token: 167.4937
# └── TRAINING:
#     └── learning_rate: 0.001000
# Generating with greedy search...
#
# 📊 Metrics (Epoch 47):
# ├── TRAIN:
# │   ├── ce_loss_char: 1.2421
# │   ├── ce_loss_token: 5.1394
# │   ├── perplexity_char: 3.4627
# │   └── perplexity_token: 170.6075
# └── VAL:
#     ├── ce_loss_char: 1.2367
#     ├── ce_loss_token: 5.1171
#     ├── perplexity_char: 3.4442
#     └── perplexity_token: 166.8572
# └── TRAINING:
#     └── learning_rate: 0.001000
# Generating with greedy search...
#
# 📊 Metrics (Epoch 48):
# ├── TRAIN:
# │   ├── ce_loss_char: 1.2404
# │   ├── ce_loss_token: 5.1325
# │   ├── perplexity_char: 3.4570
# │   └── perplexity_token: 169.4475
# └── VAL:
#     ├── ce_loss_char: 1.2345
#     ├── ce_loss_token: 5.1081
#     ├── perplexity_char: 3.4367
#     └── perplexity_token: 165.3573
# └── TRAINING:
#     └── learning_rate: 0.001000
# Generating with greedy search...
#
# 📊 Metrics (Epoch 49):
# ├── TRAIN:
# │   ├── ce_loss_char: 1.2393
# │   ├── ce_loss_token: 5.1281
# │   ├── perplexity_char: 3.4533
# │   └── perplexity_token: 168.6898
# └── VAL:
#     ├── ce_loss_char: 1.2339
#     ├── ce_loss_token: 5.1058
#     ├── perplexity_char: 3.4348
#     └── perplexity_token: 164.9774
# └── TRAINING:
#     └── learning_rate: 0.001000

# %% [markdown]
# # Evaluate

# %%
test_metrics, test_generation_results = trainer.evaluate(test_loader)
# Cleanup
trainer.cleanup()
# Out:
# 📊 Metrics (Epoch 50):
# └── TEST:
#     ├── ce_loss_char: 1.2339
#     ├── ce_loss_token: 5.1058
#     ├── perplexity_char: 3.4348
#     └── perplexity_token: 164.9774
# └── TRAINING:
#     └── learning_rate: 0.001000
# Generating with greedy search...
# Generating with beam search...
# Could not generate results for beam:
# Generating with sampling...
# Could not generate results for sample:
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>test/ce_loss_char</td><td>▁</td></tr><tr><td>test/ce_loss_token</td><td>▁</td></tr><tr><td>test/perplexity_char</td><td>▁</td></tr><tr><td>test/perplexity_token</td><td>▁</td></tr><tr><td>train/ce_loss_char</td><td>█▇▇▇▆▆▆▆▆▆▅▅▅▅▅▅▆▅▆▅▅▄▄▃▃▄▄▄▃▃▃▃▂▂▂▂▁▁▂▁</td></tr><tr><td>train/ce_loss_token</td><td>█▇▇▇▆▆▆▆▆▆▅▅▅▅▅▅▅▅▆▅▅▄▄▃▃▄▄▃▃▂▃▂▂▂▂▁▁▁▂▁</td></tr><tr><td>train/perplexity_char</td><td>█▇▇▇▆▆▆▆▆▆▅▅▅▅▅▅▅▅▆▅▅▄▄▃▃▃▄▄▃▃▃▃▂▂▂▂▁▁▂▁</td></tr><tr><td>train/perplexity_token</td><td>█▇▇▆▆▆▆▆▆▅▅▅▅▅▅▅▅▅▆▅▄▄▄▃▃▃▄▃▃▂▃▂▂▂▂▁▁▁▁▁</td></tr><tr><td>val/ce_loss_char</td><td>██▇▇▇▇▇▇▇▆▆▆▆▆▆▆▆▆▆▆▅▅▄▄▃▄▄▃▃▃▃▃▃▃▂▂▁▁▂▁</td></tr><tr><td>val/ce_loss_token</td><td>██▇▇▇▇▇▇▇▆▆▆▆▆▆▆▆▆▆▆▅▄▄▃▃▄▄▃▃▃▃▃▃▃▂▂▁▁▂▁</td></tr><tr><td>val/perplexity_char</td><td>██▇▇▇▇▇▇▆▆▆▆▆▆▆▆▆▆▆▅▄▄▃▃▃▄▄▃▃▃▃▂▃▂▂▁▁▂▂▁</td></tr><tr><td>val/perplexity_token</td><td>██▇▇▇▇▇▇▆▆▆▆▆▆▆▆▆▆▆▅▄▄▃▃▄▄▃▃▃▃▃▂▃▂▂▁▁▂▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>learning_rate</td><td>0.001</td></tr><tr><td>test/ce_loss_char</td><td>1.23395</td></tr><tr><td>test/ce_loss_token</td><td>5.10581</td></tr><tr><td>test/perplexity_char</td><td>3.43477</td></tr><tr><td>test/perplexity_token</td><td>164.97736</td></tr><tr><td>train/ce_loss_char</td><td>1.23933</td></tr><tr><td>train/ce_loss_token</td><td>5.12806</td></tr><tr><td>train/perplexity_char</td><td>3.45329</td></tr><tr><td>train/perplexity_token</td><td>168.68983</td></tr><tr><td>val/ce_loss_char</td><td>1.23395</td></tr><tr><td>val/ce_loss_token</td><td>5.10581</td></tr><tr><td>val/perplexity_char</td><td>3.43477</td></tr><tr><td>val/perplexity_token</td><td>164.97736</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">test-lm</strong> at: <a href='https://wandb.ai/sashok2-carnegie-mellon-university/HW4P1/runs/so9wjy3c' target="_blank">https://wandb.ai/sashok2-carnegie-mellon-university/HW4P1/runs/so9wjy3c</a><br> View project at: <a href='https://wandb.ai/sashok2-carnegie-mellon-university/HW4P1' target="_blank">https://wandb.ai/sashok2-carnegie-mellon-university/HW4P1</a><br>Synced 5 W&B file(s), 101 media file(s), 0 artifact file(s) and 53 other file(s)
# Find logs at: <code>.\wandb\run-20251111_201701-so9wjy3c\logs</code>

# %% [markdown]
# # Submission
# To submit your assignment, you will need to create a `handin.tar` with the following directory structure:
#
# ```
# handin/
# ├── mytorch/                     # Your implemented modules
# ├── test_metrics.json            # Results from evaluation
# ├── test_generated_results.json  # Sample text generations
# └── model_arch.txt               # Model architecture summary
# ```
#
# - Simply run the cell below once you are satisfied with your current state and this will create the `handin.tar` file.
# - After running the above cell, you should see the handin.tar file in the current directory
# - Upload the `handin.tar` file to the `HW4P1` assignment on Autolab.

# %%
# Create temporary handin directory
if os.path.exists('handin'):
    shutil.rmtree('handin')
os.makedirs('handin')

# Copy mytorch directory
shutil.copytree('mytorch', 'handin/mytorch')

# Save final results
with open('handin/test_metrics.json', 'w') as f:
    json.dump(test_metrics, f, indent=4)

with open('handin/test_generated_results.json', 'w') as f:
    json.dump(test_generation_results['greedy'], f, indent=4)

# Save model architecture
with open('handin/model_arch.txt', 'w') as f:
    f.write(str(model_stats))

# Create tar file with all exclusions handled by filter
with tarfile.open('handin.tar', 'w') as tar:
    def filter_files(tarinfo):
        # Skip unwanted files
        if any(pattern in tarinfo.name for pattern in [
            '.DS_Store',
            '__pycache__',
            '.pyc'
        ]):
            return None
        return tarinfo

    tar.add('handin', arcname='handin', filter=filter_files)

# Cleanup
shutil.rmtree('handin')

print("Created handin.tar successfully!")

## After running the above cell, you should see the handin.tar file in the current directory
# !ls
# Out:
# Created handin.tar successfully!
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.
